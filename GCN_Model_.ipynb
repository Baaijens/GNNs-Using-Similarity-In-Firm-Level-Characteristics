# %% [markdown]
# Set up OS

# %%
# !pip install google-auth google-auth-oauthlib google-auth-httplib2
# !pip install google-api-python-client
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import os
os.chdir('/content/drive/My Drive')

# %% [markdown]
# # Imports

# %%
# !pip install torch_geometric

import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
import torch.optim as optim
import pandas as pd
from torch_geometric.loader import DataLoader
import itertools
import os
from torch_geometric.data import DataLoader, Data
from glob import glob

# %% [markdown]
# # Import Graph Data Per Panel Data Conversion Method

# %% [markdown]
# Euclidean

# %%
import os
import torch
from torch_geometric.data import DataLoader, Data
from glob import glob

def extract_parameters_from_filename(filename):
    """Extract W, sigma, and theta parameters from the given filename."""
    parts = filename.replace('.pt', '').split('_')
    W, sigma, theta = None, None, None
    for part in parts:
        if part.startswith('W'):
            W = int(part[1:])
        elif part.startswith('sigma'):
            sigma = float(part[5:])
        elif part.startswith('theta'):
            theta = float(part[5:])
    return W, sigma, theta

def load_all_graphs(W, sigma, theta):
    """Load all graphs matching the given W, sigma, and theta parameters."""
    save_dir = f"Pair(1963 New)_Min_FILTERED_W{W}_sigma{sigma}_theta{theta}"
    all_files = glob(os.path.join(save_dir, 'Pair(1963 New)_Min_FILTERED_*.pt'))
    all_data = []

    for file_path in all_files:
        basename = os.path.basename(file_path)
        W_file, sigma_file, theta_file = extract_parameters_from_filename(basename)
        if W == W_file and sigma == sigma_file and theta == theta_file:
            graph_data = torch.load(file_path)
            all_data.append(graph_data)

    return all_data

# Specify parameters
W_target = 36
sigma_target = 1
theta_target = 0.00001

# Load all matching data
all_data = load_all_graphs(W=W_target, sigma=sigma_target, theta=theta_target)

# %% [markdown]
# Cosine

# %%
import os
import torch
from torch_geometric.data import DataLoader, Data
from glob import glob

def extract_parameters_from_filename(filename):
    """Extract W and Percentile parameters from the given filename."""
    parts = filename.replace('.pt', '').split('_')
    W, percentile = None, None
    for part in parts:
        if part.startswith('W'):
            W = int(part[1:])
        elif 'Percentile' in part:
            start = part.find('Percentile') + len('Percentile')
            end = part.find('_Abs') if '_Abs' in part else len(part)
            percentile = int(part[start:end])
    return W, percentile

def load_all_graphs(W, percentile):
    """Load all graphs matching the given W and Percentile parameters, and print nodes and edges per graph."""
    save_dir = f"Pair-cosine(1963bestSP500)_Min_FILTERED_W{W}_Percentile{percentile}"
    all_files = glob(os.path.join(save_dir, '*.pt'))
    all_data = []

    for file_path in all_files:
        basename = os.path.basename(file_path)
        W_file, percentile_file = extract_parameters_from_filename(basename)
        if W == W_file and percentile == percentile_file:
            graph_data = torch.load(file_path)
            all_data.append(graph_data)
            print(f"Graph loaded from {file_path}: {graph_data.num_nodes} nodes, {graph_data.num_edges // 2} edges.")

    return all_data

# Specify the window size and percentile parameters
W_target = 36  # Update this as needed
percentile_target = 5  # Update this as needed

# Load all matching data
all_data = load_all_graphs(W=W_target, percentile=percentile_target)

# Optional: Load into a DataLoader if using batches
# data_loader = DataLoader(all_data, batch_size=10)  # Adjust batch size as necessary

# %% [markdown]
# Pearson Correlation

# %%
import os
import torch
from torch_geometric.data import DataLoader, Data
from glob import glob

def extract_parameters_from_filename(filename):
    """Extract W and theta parameters from the given filename."""
    parts = filename.replace('.pt', '').split('_')
    W, theta = None, None
    for part in parts:
        if part.startswith('W'):
            W = int(part[1:])
        elif part.startswith('theta'):
            theta = float(part[5:])
    return W, theta

def load_all_graphs(W, theta):
    """Load all graphs matching the given W and theta parameters."""
    save_dir = f"Corrsaved(absolute)_graphs_W{W}_theta{theta}"
    all_files = glob(os.path.join(save_dir, '*.pt'))
    all_data = []

    for file_path in all_files:
        basename = os.path.basename(file_path)
        W_file, theta_file = extract_parameters_from_filename(basename)
        if W == W_file and theta == theta_file:
            graph_data = torch.load(file_path)
            all_data.append(graph_data)

    return all_data

# Specify parameters
W_target = 36
theta_target = 0.00001

# Load all matching data
all_data = load_all_graphs(W=W_target, theta=theta_target)

# %% [markdown]
# # GCN Model

# %% [markdown]
# **Data Splitting Function**

# %% [markdown]
# This function splits the dataset into training, validation, and test sets based on specified year ranges.

# %%
def split_data_by_year(data, train_years, val_years, test_years):
    """Split the provided data into training, validation, and test datasets based on year ranges."""
    train_dataset, val_dataset, test_dataset = [], [], []

    for graph_data in data:
        if graph_data.date.numel() > 0:
            year = int(str(graph_data.date[0].item())[:4])
            if train_years[0] <= year <= train_years[1]:
                train_dataset.append(graph_data)
            elif val_years[0] <= year <= val_years[1]:
                val_dataset.append(graph_data)
            elif test_years[0] <= year <= test_years[1]:
                test_dataset.append(graph_data)
    return train_dataset, val_dataset, test_dataset

# %% [markdown]
# **Custom GCN Layer**

# %% [markdown]
# This class defines a custom Graph Convolutional Network (GCN) layer:
#
# __init__: Initializes the GCN layer with input and output channels.
# forward: Defines the forward pass with a GCN convolution followed by a ReLU activation.

# %%
class CustomGCNLayer(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(CustomGCNLayer, self).__init__()
        self.gcn_conv = GCNConv(in_channels, out_channels)

    def forward(self, x, edge_index):
        x = self.gcn_conv(x, edge_index)
        return F.relu(x)

# %% [markdown]
# **GCN Model**

# %% [markdown]
# This class defines a GCN model:
#
# __init__: Initializes the model with multiple GCN layers and a final regression layer.
# forward: Processes the input data through the GCN layers and produces a final regression output.

# %%
class GCNModel(torch.nn.Module):
    def __init__(self, num_node_features, base_units, num_layers):
        super(GCNModel, self).__init__()
        self.layers = torch.nn.ModuleList()
        for i in range(num_layers):
            in_channels = num_node_features if i == 0 else base_units
            self.layers.append(CustomGCNLayer(in_channels, base_units))
        self.regressor = torch.nn.Linear(base_units, 1)

    def forward(self, data):
        x, edge_index = data.x[:, :-1], data.edge_index
        for layer in self.layers:
            x = layer(x, edge_index)
        x = self.regressor(x)
        return x

# %% [markdown]
# **Training Function**

# %% [markdown]
# This function trains the model on the provided data loader:
#
# model.train(): Puts the model in training mode.
# for data in loader: Iterates over batches of data to train the model.
# optimizer.zero_grad(): Resets gradients.
# loss.backward(): Computes gradients.
# optimizer.step(): Updates model parameters.

# %%
def train(model, loader, optimizer, criterion, l1_lambda, device):
    model.train()
    total_loss = 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        target = data.x[:, -1].view(-1, 1).to(device)
        mse_loss = criterion(out, target)
        l1_loss = sum(p.abs().sum() for p in model.parameters())
        loss = mse_loss + l1_lambda * l1_loss
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

# %% [markdown]
# **Validation Function**

# %% [markdown]
# This function validates the model:
#
# model.eval(): Puts the model in evaluation mode.
# with torch.no_grad(): Disables gradient computation for validation.
# for data in loader: Iterates over batches of data to validate the model.

# %%
def validate(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data)
            target = data.x[:, -1].view(-1, 1).to(device)
            loss = criterion(out, target)
            total_loss += loss.item()
    return total_loss / len(loader)

# %% [markdown]
# **Training and Evaluating Across Years**

# %% [markdown]
# This function trains and evaluates the model across multiple years:
#
# for test_year in range(start_year, end_year + 1): Iterates over each test year.
# split_data_by_year: Splits the data for each test year.
# for params in itertools.product(*hyperparams.values()): Iterates over all hyperparameter combinations.
# train: Trains the model.
# validate: Validates the model.
# ensemble_predictions: Averages predictions over multiple runs.

# %%
def train_and_evaluate_all_years(data, start_year, end_year, num_ensemble_runs=10):
    results_df = pd.DataFrame()

    for test_year in range(start_year, end_year + 1):
        print(f"\nStarting evaluations for test year: {test_year}")
        train_years = (1969, 1986 + (test_year - 1999))
        val_years = (1987 + (test_year - 1999), 1998 + (test_year - 1999))
        test_years = (test_year, test_year)

        train_dataset, val_dataset, test_dataset = split_data_by_year(data, train_years, val_years, test_years)

        best_loss = float('inf')
        best_params = {}
        patience = 5
        best_model = None

        for params in itertools.product(*hyperparams.values()):
            lr, num_layers, base_units, batch_size, dropout_rate, l1_lambda = params
            model = GCNModel(num_node_features-1, base_units, num_layers).to(device)
            optimizer = torch.optim.Adam(model.parameters(), lr=lr)
            criterion = torch.nn.MSELoss()
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

            best_val_loss = float('inf')
            epochs_no_improve = 0
            for epoch in range(500):
                train_loss = train(model, train_loader, optimizer, criterion, l1_lambda, device)
                val_loss = validate(model, val_loader, criterion, device)
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    best_model = model
                    epochs_no_improve = 0
                    print(f"Validation improvement at epoch {epoch+1}, loss: {val_loss:.4f}")
                else:
                    epochs_no_improve += 1
                    if epochs_no_improve >= patience:
                        print(f"Early stopping triggered after {epoch+1} epochs for test year {test_year}.")
                        break

            if best_val_loss < best_loss:
                best_loss = best_val_loss
                best_params = dict(zip(hyperparams.keys(), params), epochs=epoch+1)

        print(f"Best parameters for year {test_year}: {best_params}")
        print(f"Best validation loss for year {test_year}: {best_loss:.4f}")

        ensemble_predictions = []
        identifiers_list = []
        true_values = []
        for run in range(num_ensemble_runs):
            full_train_data = train_dataset + val_dataset
            full_train_loader = DataLoader(full_train_data, batch_size=best_params['batch_size'], shuffle=True)
            model = GCNModel(num_node_features-1, best_params['base_units'], best_params['num_layers']).to(device)
            optimizer = torch.optim.Adam(model.parameters(), lr=best_params['learning_rate'])
            for epoch in range(best_params['epochs']):
                train_loss = train(model, full_train_loader, optimizer, criterion, best_params['l1_lambda'], device)
                print(f"Retraining on full data at epoch {epoch+1}, loss: {train_loss:.4f} for ensemble run {run+1}")

            test_loader = DataLoader(test_dataset, batch_size=best_params['batch_size'], shuffle=False)
            predictions, identifiers, truths = predict_with_truths(model, test_loader, device)
            ensemble_predictions.append(predictions)
            identifiers_list = identifiers
            true_values.append(truths)
            print(f"Run {run+1}, Test Prediction Completed. Mean prediction: {sum(predictions)/len(predictions):.4f}")

        mean_predictions = [sum(preds) / num_ensemble_runs for preds in zip(*ensemble_predictions)]
        mean_true_values = [sum(trues) / num_ensemble_runs for trues in zip(*true_values)]
        year_results = pd.DataFrame({
            'Permno': [id[0] for id in identifiers_list],
            'Date': [id[1] for id in identifiers_list],
            'Prediction': mean_predictions,
            'True': mean_true_values,
            'Test_Year': [test_year]*len(mean_predictions)
        })
        results_df = pd.concat([results_df, year_results], ignore_index=True)

    return results_df

# %% [markdown]
# **Predict with Truths Function**

# %% [markdown]
# This function generates predictions and collects true values from the data:
#
# model.eval(): Sets the model to evaluation mode.
# with torch.no_grad(): Disables gradient computation.
# identifiers.extend(zip(permnos, dates)): Collects unique identifiers for each data point.

# %%
def predict_with_truths(model, loader, device):
    model.eval()
    predictions = []
    identifiers = []
    truths = []
    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            output = model(batch)
            predictions.extend(output.view(-1).tolist())
            truths.extend(batch.x[:, -1].view(-1).tolist())

            if hasattr(batch, 'permno') and hasattr(batch, 'date'):
                permnos = batch.permno.tolist()
                dates = batch.date.tolist()
                identifiers.extend(zip(permnos, dates))
            else:
                raise AttributeError("Batch does not contain 'permno' or 'date' attributes. Please check your dataset structure.")

    return predictions, identifiers, truths

# %% [markdown]
# **Final Execution**

# %% [markdown]
# This final section:
#
# train_and_evaluate_all_years: Trains and evaluates the model across the specified years.
# save_results: Saves the results to CSV files.
# results_df.to_csv: Saves the aggregated results to a final CSV file.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_node_features = 20
hyperparams = {
    'learning_rate': [0.001],
    'num_layers': [2],
    'base_units': [8, 16, 32],
    'batch_size': [24],
    'dropout_rate': [0.3],
    'l1_lambda': [0]
}


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
results_df = train_and_evaluate_all_years(all_data, 1999, 2022)
print("Aggregated results across all years")



file_name = f'Thesis Tilburg GNN/ResultsDF/Results_GCN_1963_Correlation(absolute)_Min_W{W_target}_theta{theta_target}.csv'

results_df.to_csv(file_name, index=False)



# Constructing the file name dynamically based on the variables
#file_name = f'Thesis Tilburg GNN/ResultsDF/Results_GCN_1963_Correlation(absolute)_Min_W{W_target}_theta{theta_target}.csv'

# Saving the DataFrame to CSV with the dynamically generated file name
#results_df.to_csv(file_name, index=False)

#file_name = f'Thesis Tilburg GNN/ResultsDF/Results_GCN_1963_Cosine_Min_W{W_target}_Percentile{percentile_target}.csv'
#esults_df.to_csv(file_name, index=False)

#file_name = f'Thesis Tilburg GNN/ResultsDF/Results_GCN_1963_Correlation(absolute)_Min_W{W_target}_theta{theta_target}.csv'

#results_df.to_csv(file_name, index=False)
# Out:
# Starting evaluations for test year: 1999
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Validation improvement at epoch 1, loss: 0.0349
# Validation improvement at epoch 2, loss: 0.0285
# Validation improvement at epoch 3, loss: 0.0227
# Validation improvement at epoch 4, loss: 0.0176
# Validation improvement at epoch 5, loss: 0.0134
# Validation improvement at epoch 6, loss: 0.0103
# Validation improvement at epoch 7, loss: 0.0083
# Validation improvement at epoch 8, loss: 0.0073
# Validation improvement at epoch 9, loss: 0.0070
# Validation improvement at epoch 10, loss: 0.0069
# Early stopping triggered after 15 epochs for test year 1999.
# Validation improvement at epoch 1, loss: 0.0371
# Validation improvement at epoch 2, loss: 0.0281
# Validation improvement at epoch 3, loss: 0.0200
# Validation improvement at epoch 4, loss: 0.0136
# Validation improvement at epoch 5, loss: 0.0093
# Validation improvement at epoch 6, loss: 0.0073
# Validation improvement at epoch 7, loss: 0.0069
# Validation improvement at epoch 10, loss: 0.0069
# Early stopping triggered after 15 epochs for test year 1999.
# Validation improvement at epoch 1, loss: 0.0100
# Validation improvement at epoch 2, loss: 0.0077
# Validation improvement at epoch 3, loss: 0.0069
# Validation improvement at epoch 5, loss: 0.0069
# Early stopping triggered after 10 epochs for test year 1999.
# Best parameters for year 1999: {'learning_rate': 0.001, 'num_layers': 2, 'base_units': 16, 'batch_size': 24, 'dropout_rate': 0.3, 'l1_lambda': 0, 'epochs': 15}
# Best validation loss for year 1999: 0.0069
# Retraining on full data at epoch 1, loss: 0.0183 for ensemble run 1
# Retraining on full data at epoch 2, loss: 0.0108 for ensemble run 1
# Retraining on full data at epoch 3, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 4, loss: 0.0083 for ensemble run 1
# Retraining on full data at epoch 5, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 1
# Run 1, Test Prediction Completed. Mean prediction: 0.0060
# Retraining on full data at epoch 1, loss: 0.0121 for ensemble run 2
# Retraining on full data at epoch 2, loss: 0.0098 for ensemble run 2
# Retraining on full data at epoch 3, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 4, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 5, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 2
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 2
# Run 2, Test Prediction Completed. Mean prediction: 0.0083
# Retraining on full data at epoch 1, loss: 0.0343 for ensemble run 3
# Retraining on full data at epoch 2, loss: 0.0253 for ensemble run 3
# Retraining on full data at epoch 3, loss: 0.0174 for ensemble run 3
# Retraining on full data at epoch 4, loss: 0.0118 for ensemble run 3
# Retraining on full data at epoch 5, loss: 0.0089 for ensemble run 3
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 3
# Run 3, Test Prediction Completed. Mean prediction: 0.0067
# Retraining on full data at epoch 1, loss: 0.0404 for ensemble run 4
# Retraining on full data at epoch 2, loss: 0.0256 for ensemble run 4
# Retraining on full data at epoch 3, loss: 0.0139 for ensemble run 4
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 5, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 4
# Run 4, Test Prediction Completed. Mean prediction: 0.0093
# Retraining on full data at epoch 1, loss: 0.0190 for ensemble run 5
# Retraining on full data at epoch 2, loss: 0.0121 for ensemble run 5
# Retraining on full data at epoch 3, loss: 0.0087 for ensemble run 5
# Retraining on full data at epoch 4, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 5, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 5
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 5
# Run 5, Test Prediction Completed. Mean prediction: 0.0058
# Retraining on full data at epoch 1, loss: 0.0275 for ensemble run 6
# Retraining on full data at epoch 2, loss: 0.0163 for ensemble run 6
# Retraining on full data at epoch 3, loss: 0.0096 for ensemble run 6
# Retraining on full data at epoch 4, loss: 0.0083 for ensemble run 6
# Retraining on full data at epoch 5, loss: 0.0083 for ensemble run 6
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 6
# Run 6, Test Prediction Completed. Mean prediction: 0.0077
# Retraining on full data at epoch 1, loss: 0.0431 for ensemble run 7
# Retraining on full data at epoch 2, loss: 0.0259 for ensemble run 7
# Retraining on full data at epoch 3, loss: 0.0129 for ensemble run 7
# Retraining on full data at epoch 4, loss: 0.0084 for ensemble run 7
# Retraining on full data at epoch 5, loss: 0.0084 for ensemble run 7
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 7
# Run 7, Test Prediction Completed. Mean prediction: 0.0063
# Retraining on full data at epoch 1, loss: 0.0178 for ensemble run 8
# Retraining on full data at epoch 2, loss: 0.0100 for ensemble run 8
# Retraining on full data at epoch 3, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 4, loss: 0.0083 for ensemble run 8
# Retraining on full data at epoch 5, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 8
# Run 8, Test Prediction Completed. Mean prediction: 0.0072
# Retraining on full data at epoch 1, loss: 0.0542 for ensemble run 9
# Retraining on full data at epoch 2, loss: 0.0326 for ensemble run 9
# Retraining on full data at epoch 3, loss: 0.0159 for ensemble run 9
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 5, loss: 0.0083 for ensemble run 9
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 9
# Run 9, Test Prediction Completed. Mean prediction: 0.0067
# Retraining on full data at epoch 1, loss: 0.0343 for ensemble run 10
# Retraining on full data at epoch 2, loss: 0.0199 for ensemble run 10
# Retraining on full data at epoch 3, loss: 0.0107 for ensemble run 10
# Retraining on full data at epoch 4, loss: 0.0083 for ensemble run 10
# Retraining on full data at epoch 5, loss: 0.0083 for ensemble run 10
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 11, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 12, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 13, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 14, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 15, loss: 0.0082 for ensemble run 10
# Run 10, Test Prediction Completed. Mean prediction: 0.0084
#
# Starting evaluations for test year: 2000
# Validation improvement at epoch 1, loss: 0.0070
# Validation improvement at epoch 2, loss: 0.0067
# Validation improvement at epoch 7, loss: 0.0067
# Early stopping triggered after 12 epochs for test year 2000.
# Validation improvement at epoch 1, loss: 0.0072
# Validation improvement at epoch 2, loss: 0.0067
# Validation improvement at epoch 5, loss: 0.0067
# Early stopping triggered after 10 epochs for test year 2000.
# Validation improvement at epoch 1, loss: 0.0151
# Validation improvement at epoch 2, loss: 0.0091
# Validation improvement at epoch 3, loss: 0.0067
# Validation improvement at epoch 6, loss: 0.0067
# Validation improvement at epoch 7, loss: 0.0067
# Early stopping triggered after 12 epochs for test year 2000.
# Best parameters for year 2000: {'learning_rate': 0.001, 'num_layers': 2, 'base_units': 16, 'batch_size': 24, 'dropout_rate': 0.3, 'l1_lambda': 0, 'epochs': 10}
# Best validation loss for year 2000: 0.0067
# Retraining on full data at epoch 1, loss: 0.0101 for ensemble run 1
# Retraining on full data at epoch 2, loss: 0.0083 for ensemble run 1
# Retraining on full data at epoch 3, loss: 0.0084 for ensemble run 1
# Retraining on full data at epoch 4, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 5, loss: 0.0084 for ensemble run 1
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 1
# Retraining on full data at epoch 8, loss: 0.0083 for ensemble run 1
# Retraining on full data at epoch 9, loss: 0.0083 for ensemble run 1
# Retraining on full data at epoch 10, loss: 0.0083 for ensemble run 1
# Run 1, Test Prediction Completed. Mean prediction: 0.0066
# Retraining on full data at epoch 1, loss: 0.0084 for ensemble run 2
# Retraining on full data at epoch 2, loss: 0.0083 for ensemble run 2
# Retraining on full data at epoch 3, loss: 0.0083 for ensemble run 2
# Retraining on full data at epoch 4, loss: 0.0083 for ensemble run 2
# Retraining on full data at epoch 5, loss: 0.0084 for ensemble run 2
# Retraining on full data at epoch 6, loss: 0.0083 for ensemble run 2
# Retraining on full data at epoch 7, loss: 0.0083 for ensemble run 2
# Retraining on full data at epoch 8, loss: 0.0083 for ensemble run 2
# Retraining on full data at epoch 9, loss: 0.0084 for ensemble run 2
# Retraining on full data at epoch 10, loss: 0.0083 for ensemble run 2
# Run 2, Test Prediction Completed. Mean prediction: 0.0075
# Retraining on full data at epoch 1, loss: 0.0137 for ensemble run 3
# Retraining on full data at epoch 2, loss: 0.0091 for ensemble run 3
# Retraining on full data at epoch 3, loss: 0.0083 for ensemble run 3
# Retraining on full data at epoch 4, loss: 0.0083 for ensemble run 3
# Retraining on full data at epoch 5, loss: 0.0084 for ensemble run 3
# Retraining on full data at epoch 6, loss: 0.0084 for ensemble run 3
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 3
# Retraining on full data at epoch 9, loss: 0.0083 for ensemble run 3
# Retraining on full data at epoch 10, loss: 0.0084 for ensemble run 3
# Run 3, Test Prediction Completed. Mean prediction: 0.0057
# Retraining on full data at epoch 1, loss: 0.0642 for ensemble run 4
# Retraining on full data at epoch 2, loss: 0.0433 for ensemble run 4
# Retraining on full data at epoch 3, loss: 0.0240 for ensemble run 4
# Retraining on full data at epoch 4, loss: 0.0117 for ensemble run 4
# Retraining on full data at epoch 5, loss: 0.0083 for ensemble run 4
# Retraining on full data at epoch 6, loss: 0.0083 for ensemble run 4
# Retraining on full data at epoch 7, loss: 0.0083 for ensemble run 4
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 4
# Retraining on full data at epoch 9, loss: 0.0083 for ensemble run 4
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 4
# Run 4, Test Prediction Completed. Mean prediction: 0.0080
# Retraining on full data at epoch 1, loss: 0.0317 for ensemble run 5
# Retraining on full data at epoch 2, loss: 0.0211 for ensemble run 5
# Retraining on full data at epoch 3, loss: 0.0131 for ensemble run 5
# Retraining on full data at epoch 4, loss: 0.0090 for ensemble run 5
# Retraining on full data at epoch 5, loss: 0.0084 for ensemble run 5
# Retraining on full data at epoch 6, loss: 0.0084 for ensemble run 5
# Retraining on full data at epoch 7, loss: 0.0084 for ensemble run 5
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 9, loss: 0.0083 for ensemble run 5
# Retraining on full data at epoch 10, loss: 0.0083 for ensemble run 5
# Run 5, Test Prediction Completed. Mean prediction: 0.0094
# Retraining on full data at epoch 1, loss: 0.0128 for ensemble run 6
# Retraining on full data at epoch 2, loss: 0.0101 for ensemble run 6
# Retraining on full data at epoch 3, loss: 0.0087 for ensemble run 6
# Retraining on full data at epoch 4, loss: 0.0083 for ensemble run 6
# Retraining on full data at epoch 5, loss: 0.0083 for ensemble run 6
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 7, loss: 0.0083 for ensemble run 6
# Retraining on full data at epoch 8, loss: 0.0083 for ensemble run 6
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 6
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 6
# Run 6, Test Prediction Completed. Mean prediction: 0.0071
# Retraining on full data at epoch 1, loss: 0.0140 for ensemble run 7
# Retraining on full data at epoch 2, loss: 0.0090 for ensemble run 7
# Retraining on full data at epoch 3, loss: 0.0083 for ensemble run 7
# Retraining on full data at epoch 4, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 5, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 6, loss: 0.0083 for ensemble run 7
# Retraining on full data at epoch 7, loss: 0.0084 for ensemble run 7
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 7
# Retraining on full data at epoch 9, loss: 0.0083 for ensemble run 7
# Retraining on full data at epoch 10, loss: 0.0082 for ensemble run 7
# Run 7, Test Prediction Completed. Mean prediction: 0.0058
# Retraining on full data at epoch 1, loss: 0.0083 for ensemble run 8
# Retraining on full data at epoch 2, loss: 0.0083 for ensemble run 8
# Retraining on full data at epoch 3, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 4, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 5, loss: 0.0083 for ensemble run 8
# Retraining on full data at epoch 6, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 7, loss: 0.0083 for ensemble run 8
# Retraining on full data at epoch 8, loss: 0.0082 for ensemble run 8
# Retraining on full data at epoch 9, loss: 0.0083 for ensemble run 8
# Retraining on full data at epoch 10, loss: 0.0083 for ensemble run 8
# Run 8, Test Prediction Completed. Mean prediction: 0.0057
# Retraining on full data at epoch 1, loss: 0.0335 for ensemble run 9
# Retraining on full data at epoch 2, loss: 0.0222 for ensemble run 9
# Retraining on full data at epoch 3, loss: 0.0135 for ensemble run 9
# Retraining on full data at epoch 4, loss: 0.0091 for ensemble run 9
# Retraining on full data at epoch 5, loss: 0.0083 for ensemble run 9
# Retraining on full data at epoch 6, loss: 0.0084 for ensemble run 9
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 8, loss: 0.0083 for ensemble run 9
# Retraining on full data at epoch 9, loss: 0.0082 for ensemble run 9
# Retraining on full data at epoch 10, loss: 0.0083 for ensemble run 9
# Run 9, Test Prediction Completed. Mean prediction: 0.0072
# Retraining on full data at epoch 1, loss: 0.0259 for ensemble run 10
# Retraining on full data at epoch 2, loss: 0.0147 for ensemble run 10
# Retraining on full data at epoch 3, loss: 0.0091 for ensemble run 10
# Retraining on full data at epoch 4, loss: 0.0084 for ensemble run 10
# Retraining on full data at epoch 5, loss: 0.0084 for ensemble run 10
# Retraining on full data at epoch 6, loss: 0.0083 for ensemble run 10
# Retraining on full data at epoch 7, loss: 0.0082 for ensemble run 10
# Retraining on full data at epoch 8, loss: 0.0084 for ensemble run 10
# Retraining on full data at epoch 9, loss: 0.0083 for ensemble run 10
# Retraining on full data at epoch 10, loss: 0.0084 for ensemble run 10
# Run 10, Test Prediction Completed. Mean prediction: 0.0080
#
# Starting evaluations for test year: 2001
# Validation improvement at epoch 1, loss: 0.0075
# Validation improvement at epoch 2, loss: 0.0075
# Validation improvement at epoch 3, loss: 0.0075
# Early stopping triggered after 8 epochs for test year 2001.
# Validation improvement at epoch 1, loss: 0.0159
# Validation improvement at epoch 2, loss: 0.0119
# Validation improvement at epoch 3, loss: 0.0091
# Validation improvement at epoch 4, loss: 0.0078
# Validation improvement at epoch 5, loss: 0.0075
# Validation improvement at epoch 10, loss: 0.0075
# Early stopping triggered after 15 epochs for test year 2001.
# Validation improvement at epoch 1, loss: 0.0127
# Validation improvement at epoch 2, loss: 0.0084
# Validation improvement at epoch 3, loss: 0.0075
# Validation improvement at epoch 5, loss: 0.0075
# Validation improvement at epoch 9, loss: 0.0075
# Early stopping triggered after 14 epochs for test year 2001.
# Best parameters for year 2001: {'learning_rate': 0.001, 'num_layers': 2, 'base_units': 32, 'batch_size': 24, 'dropout_rate': 0.3, 'l1_lambda': 0, 'epochs': 14}
# Best validation loss for year 2001: 0.0075
# Retraining on full data at epoch 1, loss: 0.0095 for ensemble run 1
# Retraining on full data at epoch 2, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 3, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 1
# Run 1, Test Prediction Completed. Mean prediction: 0.0108
# Retraining on full data at epoch 1, loss: 0.0323 for ensemble run 2
# Retraining on full data at epoch 2, loss: 0.0197 for ensemble run 2
# Retraining on full data at epoch 3, loss: 0.0104 for ensemble run 2
# Retraining on full data at epoch 4, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 2
# Run 2, Test Prediction Completed. Mean prediction: 0.0061
# Retraining on full data at epoch 1, loss: 0.0181 for ensemble run 3
# Retraining on full data at epoch 2, loss: 0.0097 for ensemble run 3
# Retraining on full data at epoch 3, loss: 0.0087 for ensemble run 3
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 3
# Run 3, Test Prediction Completed. Mean prediction: 0.0063
# Retraining on full data at epoch 1, loss: 0.0120 for ensemble run 4
# Retraining on full data at epoch 2, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 3, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 4
# Run 4, Test Prediction Completed. Mean prediction: 0.0089
# Retraining on full data at epoch 1, loss: 0.0140 for ensemble run 5
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 3, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 5
# Run 5, Test Prediction Completed. Mean prediction: 0.0083
# Retraining on full data at epoch 1, loss: 0.0108 for ensemble run 6
# Retraining on full data at epoch 2, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 3, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 6
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 6
# Run 6, Test Prediction Completed. Mean prediction: 0.0052
# Retraining on full data at epoch 1, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 2, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 3, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 7
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 7
# Run 7, Test Prediction Completed. Mean prediction: 0.0053
# Retraining on full data at epoch 1, loss: 0.0087 for ensemble run 8
# Retraining on full data at epoch 2, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 3, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 8
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 8
# Run 8, Test Prediction Completed. Mean prediction: 0.0062
# Retraining on full data at epoch 1, loss: 0.0090 for ensemble run 9
# Retraining on full data at epoch 2, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 3, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 9
# Run 9, Test Prediction Completed. Mean prediction: 0.0096
# Retraining on full data at epoch 1, loss: 0.0097 for ensemble run 10
# Retraining on full data at epoch 2, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 3, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 14, loss: 0.0085 for ensemble run 10
# Run 10, Test Prediction Completed. Mean prediction: 0.0064
#
# Starting evaluations for test year: 2002
# Validation improvement at epoch 1, loss: 0.0110
# Validation improvement at epoch 2, loss: 0.0092
# Validation improvement at epoch 3, loss: 0.0083
# Validation improvement at epoch 4, loss: 0.0081
# Validation improvement at epoch 8, loss: 0.0081
# Validation improvement at epoch 10, loss: 0.0081
# Validation improvement at epoch 13, loss: 0.0081
# Validation improvement at epoch 14, loss: 0.0081
# Validation improvement at epoch 15, loss: 0.0081
# Early stopping triggered after 20 epochs for test year 2002.
# Validation improvement at epoch 1, loss: 0.0115
# Validation improvement at epoch 2, loss: 0.0095
# Validation improvement at epoch 3, loss: 0.0084
# Validation improvement at epoch 4, loss: 0.0081
# Validation improvement at epoch 7, loss: 0.0081
# Early stopping triggered after 12 epochs for test year 2002.
# Validation improvement at epoch 1, loss: 0.0138
# Validation improvement at epoch 2, loss: 0.0103
# Validation improvement at epoch 3, loss: 0.0083
# Validation improvement at epoch 4, loss: 0.0081
# Validation improvement at epoch 6, loss: 0.0081
# Validation improvement at epoch 9, loss: 0.0081
# Early stopping triggered after 14 epochs for test year 2002.
# Best parameters for year 2002: {'learning_rate': 0.001, 'num_layers': 2, 'base_units': 8, 'batch_size': 24, 'dropout_rate': 0.3, 'l1_lambda': 0, 'epochs': 20}
# Best validation loss for year 2002: 0.0081
# Retraining on full data at epoch 1, loss: 0.0335 for ensemble run 1
# Retraining on full data at epoch 2, loss: 0.0218 for ensemble run 1
# Retraining on full data at epoch 3, loss: 0.0138 for ensemble run 1
# Retraining on full data at epoch 4, loss: 0.0096 for ensemble run 1
# Retraining on full data at epoch 5, loss: 0.0087 for ensemble run 1
# Retraining on full data at epoch 6, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 7, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 8, loss: 0.0087 for ensemble run 1
# Retraining on full data at epoch 9, loss: 0.0087 for ensemble run 1
# Retraining on full data at epoch 10, loss: 0.0087 for ensemble run 1
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 12, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 13, loss: 0.0085 for ensemble run 1
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 15, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 16, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 17, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 18, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 19, loss: 0.0086 for ensemble run 1
# Retraining on full data at epoch 20, loss: 0.0088 for ensemble run 1
# Run 1, Test Prediction Completed. Mean prediction: 0.0058
# Retraining on full data at epoch 1, loss: 0.0609 for ensemble run 2
# Retraining on full data at epoch 2, loss: 0.0467 for ensemble run 2
# Retraining on full data at epoch 3, loss: 0.0333 for ensemble run 2
# Retraining on full data at epoch 4, loss: 0.0217 for ensemble run 2
# Retraining on full data at epoch 5, loss: 0.0137 for ensemble run 2
# Retraining on full data at epoch 6, loss: 0.0096 for ensemble run 2
# Retraining on full data at epoch 7, loss: 0.0087 for ensemble run 2
# Retraining on full data at epoch 8, loss: 0.0087 for ensemble run 2
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 2
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 12, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 13, loss: 0.0087 for ensemble run 2
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 15, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 16, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 17, loss: 0.0086 for ensemble run 2
# Retraining on full data at epoch 18, loss: 0.0087 for ensemble run 2
# Retraining on full data at epoch 19, loss: 0.0087 for ensemble run 2
# Retraining on full data at epoch 20, loss: 0.0086 for ensemble run 2
# Run 2, Test Prediction Completed. Mean prediction: 0.0064
# Retraining on full data at epoch 1, loss: 0.0390 for ensemble run 3
# Retraining on full data at epoch 2, loss: 0.0246 for ensemble run 3
# Retraining on full data at epoch 3, loss: 0.0139 for ensemble run 3
# Retraining on full data at epoch 4, loss: 0.0093 for ensemble run 3
# Retraining on full data at epoch 5, loss: 0.0089 for ensemble run 3
# Retraining on full data at epoch 6, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 7, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 10, loss: 0.0087 for ensemble run 3
# Retraining on full data at epoch 11, loss: 0.0085 for ensemble run 3
# Retraining on full data at epoch 12, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 13, loss: 0.0087 for ensemble run 3
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 15, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 16, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 17, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 18, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 19, loss: 0.0086 for ensemble run 3
# Retraining on full data at epoch 20, loss: 0.0086 for ensemble run 3
# Run 3, Test Prediction Completed. Mean prediction: 0.0055
# Retraining on full data at epoch 1, loss: 0.0144 for ensemble run 4
# Retraining on full data at epoch 2, loss: 0.0104 for ensemble run 4
# Retraining on full data at epoch 3, loss: 0.0087 for ensemble run 4
# Retraining on full data at epoch 4, loss: 0.0087 for ensemble run 4
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 6, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 7, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 8, loss: 0.0087 for ensemble run 4
# Retraining on full data at epoch 9, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 10, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 12, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 13, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 15, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 16, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 17, loss: 0.0086 for ensemble run 4
# Retraining on full data at epoch 18, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 19, loss: 0.0085 for ensemble run 4
# Retraining on full data at epoch 20, loss: 0.0086 for ensemble run 4
# Run 4, Test Prediction Completed. Mean prediction: 0.0066
# Retraining on full data at epoch 1, loss: 0.0865 for ensemble run 5
# Retraining on full data at epoch 2, loss: 0.0601 for ensemble run 5
# Retraining on full data at epoch 3, loss: 0.0360 for ensemble run 5
# Retraining on full data at epoch 4, loss: 0.0188 for ensemble run 5
# Retraining on full data at epoch 5, loss: 0.0103 for ensemble run 5
# Retraining on full data at epoch 6, loss: 0.0087 for ensemble run 5
# Retraining on full data at epoch 7, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 8, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 10, loss: 0.0087 for ensemble run 5
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 12, loss: 0.0085 for ensemble run 5
# Retraining on full data at epoch 13, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 15, loss: 0.0087 for ensemble run 5
# Retraining on full data at epoch 16, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 17, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 18, loss: 0.0086 for ensemble run 5
# Retraining on full data at epoch 19, loss: 0.0087 for ensemble run 5
# Retraining on full data at epoch 20, loss: 0.0087 for ensemble run 5
# Run 5, Test Prediction Completed. Mean prediction: 0.0071
# Retraining on full data at epoch 1, loss: 0.0285 for ensemble run 6
# Retraining on full data at epoch 2, loss: 0.0194 for ensemble run 6
# Retraining on full data at epoch 3, loss: 0.0125 for ensemble run 6
# Retraining on full data at epoch 4, loss: 0.0093 for ensemble run 6
# Retraining on full data at epoch 5, loss: 0.0087 for ensemble run 6
# Retraining on full data at epoch 6, loss: 0.0087 for ensemble run 6
# Retraining on full data at epoch 7, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 8, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 10, loss: 0.0087 for ensemble run 6
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 12, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 13, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 15, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 16, loss: 0.0087 for ensemble run 6
# Retraining on full data at epoch 17, loss: 0.0087 for ensemble run 6
# Retraining on full data at epoch 18, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 19, loss: 0.0086 for ensemble run 6
# Retraining on full data at epoch 20, loss: 0.0086 for ensemble run 6
# Run 6, Test Prediction Completed. Mean prediction: 0.0077
# Retraining on full data at epoch 1, loss: 0.0525 for ensemble run 7
# Retraining on full data at epoch 2, loss: 0.0385 for ensemble run 7
# Retraining on full data at epoch 3, loss: 0.0249 for ensemble run 7
# Retraining on full data at epoch 4, loss: 0.0146 for ensemble run 7
# Retraining on full data at epoch 5, loss: 0.0095 for ensemble run 7
# Retraining on full data at epoch 6, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 7, loss: 0.0087 for ensemble run 7
# Retraining on full data at epoch 8, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 10, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 12, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 13, loss: 0.0087 for ensemble run 7
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 15, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 16, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 17, loss: 0.0087 for ensemble run 7
# Retraining on full data at epoch 18, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 19, loss: 0.0086 for ensemble run 7
# Retraining on full data at epoch 20, loss: 0.0087 for ensemble run 7
# Run 7, Test Prediction Completed. Mean prediction: 0.0068
# Retraining on full data at epoch 1, loss: 0.0768 for ensemble run 8
# Retraining on full data at epoch 2, loss: 0.0610 for ensemble run 8
# Retraining on full data at epoch 3, loss: 0.0460 for ensemble run 8
# Retraining on full data at epoch 4, loss: 0.0314 for ensemble run 8
# Retraining on full data at epoch 5, loss: 0.0199 for ensemble run 8
# Retraining on full data at epoch 6, loss: 0.0129 for ensemble run 8
# Retraining on full data at epoch 7, loss: 0.0097 for ensemble run 8
# Retraining on full data at epoch 8, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 10, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 12, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 13, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 14, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 15, loss: 0.0087 for ensemble run 8
# Retraining on full data at epoch 16, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 17, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 18, loss: 0.0086 for ensemble run 8
# Retraining on full data at epoch 19, loss: 0.0087 for ensemble run 8
# Retraining on full data at epoch 20, loss: 0.0086 for ensemble run 8
# Run 8, Test Prediction Completed. Mean prediction: 0.0054
# Retraining on full data at epoch 1, loss: 0.0739 for ensemble run 9
# Retraining on full data at epoch 2, loss: 0.0656 for ensemble run 9
# Retraining on full data at epoch 3, loss: 0.0581 for ensemble run 9
# Retraining on full data at epoch 4, loss: 0.0513 for ensemble run 9
# Retraining on full data at epoch 5, loss: 0.0455 for ensemble run 9
# Retraining on full data at epoch 6, loss: 0.0399 for ensemble run 9
# Retraining on full data at epoch 7, loss: 0.0349 for ensemble run 9
# Retraining on full data at epoch 8, loss: 0.0308 for ensemble run 9
# Retraining on full data at epoch 9, loss: 0.0273 for ensemble run 9
# Retraining on full data at epoch 10, loss: 0.0242 for ensemble run 9
# Retraining on full data at epoch 11, loss: 0.0216 for ensemble run 9
# Retraining on full data at epoch 12, loss: 0.0191 for ensemble run 9
# Retraining on full data at epoch 13, loss: 0.0172 for ensemble run 9
# Retraining on full data at epoch 14, loss: 0.0156 for ensemble run 9
# Retraining on full data at epoch 15, loss: 0.0144 for ensemble run 9
# Retraining on full data at epoch 16, loss: 0.0131 for ensemble run 9
# Retraining on full data at epoch 17, loss: 0.0122 for ensemble run 9
# Retraining on full data at epoch 18, loss: 0.0115 for ensemble run 9
# Retraining on full data at epoch 19, loss: 0.0109 for ensemble run 9
# Retraining on full data at epoch 20, loss: 0.0104 for ensemble run 9
# Run 9, Test Prediction Completed. Mean prediction: 0.0453
# Retraining on full data at epoch 1, loss: 0.0129 for ensemble run 10
# Retraining on full data at epoch 2, loss: 0.0101 for ensemble run 10
# Retraining on full data at epoch 3, loss: 0.0087 for ensemble run 10
# Retraining on full data at epoch 4, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 5, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 7, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 11, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 12, loss: 0.0087 for ensemble run 10
# Retraining on full data at epoch 13, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 14, loss: 0.0087 for ensemble run 10
# Retraining on full data at epoch 15, loss: 0.0087 for ensemble run 10
# Retraining on full data at epoch 16, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 17, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 18, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 19, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 20, loss: 0.0087 for ensemble run 10
# Run 10, Test Prediction Completed. Mean prediction: 0.0073
#
# Starting evaluations for test year: 2003
# Validation improvement at epoch 1, loss: 0.1120
# Validation improvement at epoch 2, loss: 0.0929
# ...
# Retraining on full data at epoch 2, loss: 0.0266 for ensemble run 9
# Retraining on full data at epoch 3, loss: 0.0113 for ensemble run 9
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 6, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 9
# Retraining on full data at epoch 8, loss: 0.0084 for ensemble run 9
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 9
# Retraining on full data at epoch 10, loss: 0.0085 for ensemble run 9
# Run 9, Test Prediction Completed. Mean prediction: 0.0086
# Retraining on full data at epoch 1, loss: 0.0610 for ensemble run 10
# Retraining on full data at epoch 2, loss: 0.0302 for ensemble run 10
# Retraining on full data at epoch 3, loss: 0.0121 for ensemble run 10
# Retraining on full data at epoch 4, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 5, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 6, loss: 0.0084 for ensemble run 10
# Retraining on full data at epoch 7, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 8, loss: 0.0085 for ensemble run 10
# Retraining on full data at epoch 9, loss: 0.0086 for ensemble run 10
# Retraining on full data at epoch 10, loss: 0.0084 for ensemble run 10
# Run 10, Test Prediction Completed. Mean prediction: 0.0075
#
# Starting evaluations for test year: 2021
# Validation improvement at epoch 1, loss: 0.0677
# Validation improvement at epoch 2, loss: 0.0477
# Validation improvement at epoch 3, loss: 0.0305
# Validation improvement at epoch 4, loss: 0.0182
# Validation improvement at epoch 5, loss: 0.0117
# Validation improvement at epoch 6, loss: 0.0097
# Validation improvement at epoch 7, loss: 0.0094
# Validation improvement at epoch 8, loss: 0.0094
# Early stopping triggered after 13 epochs for test year 2021.
# Validation improvement at epoch 1, loss: 0.0392
# Validation improvement at epoch 2, loss: 0.0167
# Validation improvement at epoch 3, loss: 0.0094
# Validation improvement at epoch 4, loss: 0.0094
# Early stopping triggered after 9 epochs for test year 2021.
# Validation improvement at epoch 1, loss: 0.0094
# Validation improvement at epoch 4, loss: 0.0094
# Validation improvement at epoch 8, loss: 0.0094
# Early stopping triggered after 13 epochs for test year 2021.
# Best parameters for year 2021: {'learning_rate': 0.001, 'num_layers': 2, 'base_units': 16, 'batch_size': 24, 'dropout_rate': 0.3, 'l1_lambda': 0, 'epochs': 9}
# Best validation loss for year 2021: 0.0094
# Retraining on full data at epoch 1, loss: 0.0236 for ensemble run 1
# Retraining on full data at epoch 2, loss: 0.0114 for ensemble run 1
# Retraining on full data at epoch 3, loss: 0.0089 for ensemble run 1
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 1
# Run 1, Test Prediction Completed. Mean prediction: 0.0110
# Retraining on full data at epoch 1, loss: 0.0429 for ensemble run 2
# Retraining on full data at epoch 2, loss: 0.0216 for ensemble run 2
# Retraining on full data at epoch 3, loss: 0.0099 for ensemble run 2
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 2
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 2
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 2
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 2
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 2
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 2
# Run 2, Test Prediction Completed. Mean prediction: 0.0078
# Retraining on full data at epoch 1, loss: 0.0181 for ensemble run 3
# Retraining on full data at epoch 2, loss: 0.0100 for ensemble run 3
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 3
# Run 3, Test Prediction Completed. Mean prediction: 0.0104
# Retraining on full data at epoch 1, loss: 0.0366 for ensemble run 4
# Retraining on full data at epoch 2, loss: 0.0190 for ensemble run 4
# Retraining on full data at epoch 3, loss: 0.0101 for ensemble run 4
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 4
# Run 4, Test Prediction Completed. Mean prediction: 0.0077
# Retraining on full data at epoch 1, loss: 0.0106 for ensemble run 5
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 5
# Run 5, Test Prediction Completed. Mean prediction: 0.0113
# Retraining on full data at epoch 1, loss: 0.0374 for ensemble run 6
# Retraining on full data at epoch 2, loss: 0.0219 for ensemble run 6
# Retraining on full data at epoch 3, loss: 0.0115 for ensemble run 6
# Retraining on full data at epoch 4, loss: 0.0089 for ensemble run 6
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 6
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 6
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 6
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 6
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 6
# Run 6, Test Prediction Completed. Mean prediction: 0.0077
# Retraining on full data at epoch 1, loss: 0.0547 for ensemble run 7
# Retraining on full data at epoch 2, loss: 0.0248 for ensemble run 7
# Retraining on full data at epoch 3, loss: 0.0101 for ensemble run 7
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 7
# Run 7, Test Prediction Completed. Mean prediction: 0.0061
# Retraining on full data at epoch 1, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 8
# Run 8, Test Prediction Completed. Mean prediction: 0.0057
# Retraining on full data at epoch 1, loss: 0.0093 for ensemble run 9
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 9
# Run 9, Test Prediction Completed. Mean prediction: 0.0128
# Retraining on full data at epoch 1, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 7, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 8, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 9, loss: 0.0088 for ensemble run 10
# Run 10, Test Prediction Completed. Mean prediction: 0.0077
#
# Starting evaluations for test year: 2022
# Validation improvement at epoch 1, loss: 0.0549
# Validation improvement at epoch 2, loss: 0.0415
# Validation improvement at epoch 3, loss: 0.0303
# Validation improvement at epoch 4, loss: 0.0217
# Validation improvement at epoch 5, loss: 0.0157
# Validation improvement at epoch 6, loss: 0.0119
# Validation improvement at epoch 7, loss: 0.0099
# Validation improvement at epoch 8, loss: 0.0089
# Validation improvement at epoch 9, loss: 0.0085
# Validation improvement at epoch 10, loss: 0.0084
# Validation improvement at epoch 11, loss: 0.0083
# Validation improvement at epoch 12, loss: 0.0083
# Validation improvement at epoch 13, loss: 0.0083
# Validation improvement at epoch 16, loss: 0.0083
# Early stopping triggered after 21 epochs for test year 2022.
# Validation improvement at epoch 1, loss: 0.0198
# Validation improvement at epoch 2, loss: 0.0089
# Validation improvement at epoch 3, loss: 0.0086
# Validation improvement at epoch 4, loss: 0.0083
# Validation improvement at epoch 7, loss: 0.0083
# Validation improvement at epoch 10, loss: 0.0083
# Early stopping triggered after 15 epochs for test year 2022.
# Validation improvement at epoch 1, loss: 0.0083
# Early stopping triggered after 6 epochs for test year 2022.
# Best parameters for year 2022: {'learning_rate': 0.001, 'num_layers': 2, 'base_units': 32, 'batch_size': 24, 'dropout_rate': 0.3, 'l1_lambda': 0, 'epochs': 6}
# Best validation loss for year 2022: 0.0083
# Retraining on full data at epoch 1, loss: 0.0127 for ensemble run 1
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 4, loss: 0.0087 for ensemble run 1
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 1
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 1
# Run 1, Test Prediction Completed. Mean prediction: 0.0073
# Retraining on full data at epoch 1, loss: 0.0229 for ensemble run 2
# Retraining on full data at epoch 2, loss: 0.0095 for ensemble run 2
# Retraining on full data at epoch 3, loss: 0.0089 for ensemble run 2
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 2
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 2
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 2
# Run 2, Test Prediction Completed. Mean prediction: 0.0103
# Retraining on full data at epoch 1, loss: 0.0092 for ensemble run 3
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 3, loss: 0.0087 for ensemble run 3
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 3
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 3
# Run 3, Test Prediction Completed. Mean prediction: 0.0100
# Retraining on full data at epoch 1, loss: 0.0141 for ensemble run 4
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 4
# Retraining on full data at epoch 4, loss: 0.0087 for ensemble run 4
# Retraining on full data at epoch 5, loss: 0.0087 for ensemble run 4
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 4
# Run 4, Test Prediction Completed. Mean prediction: 0.0079
# Retraining on full data at epoch 1, loss: 0.0105 for ensemble run 5
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 5
# Retraining on full data at epoch 5, loss: 0.0087 for ensemble run 5
# Retraining on full data at epoch 6, loss: 0.0089 for ensemble run 5
# Run 5, Test Prediction Completed. Mean prediction: 0.0114
# Retraining on full data at epoch 1, loss: 0.0189 for ensemble run 6
# Retraining on full data at epoch 2, loss: 0.0089 for ensemble run 6
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 6
# Retraining on full data at epoch 4, loss: 0.0087 for ensemble run 6
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 6
# Retraining on full data at epoch 6, loss: 0.0087 for ensemble run 6
# Run 6, Test Prediction Completed. Mean prediction: 0.0088
# Retraining on full data at epoch 1, loss: 0.0114 for ensemble run 7
# Retraining on full data at epoch 2, loss: 0.0089 for ensemble run 7
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 7
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 7
# Run 7, Test Prediction Completed. Mean prediction: 0.0083
# Retraining on full data at epoch 1, loss: 0.0139 for ensemble run 8
# Retraining on full data at epoch 2, loss: 0.0090 for ensemble run 8
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 4, loss: 0.0087 for ensemble run 8
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 8
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 8
# Run 8, Test Prediction Completed. Mean prediction: 0.0017
# Retraining on full data at epoch 1, loss: 0.0107 for ensemble run 9
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 3, loss: 0.0087 for ensemble run 9
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 5, loss: 0.0088 for ensemble run 9
# Retraining on full data at epoch 6, loss: 0.0088 for ensemble run 9
# Run 9, Test Prediction Completed. Mean prediction: 0.0129
# Retraining on full data at epoch 1, loss: 0.0107 for ensemble run 10
# Retraining on full data at epoch 2, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 3, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 4, loss: 0.0088 for ensemble run 10
# Retraining on full data at epoch 5, loss: 0.0087 for ensemble run 10
# Retraining on full data at epoch 6, loss: 0.0087 for ensemble run 10
# Run 10, Test Prediction Completed. Mean prediction: 0.0109
# Aggregated results across all years
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-af63fefb5bfe> in <cell line: 19>()
#      17
#      18 # Assuming results_df is the DataFrame with all predictions aggregated across years
# ---> 19 save_results(results_df)
#      20
#      21 file_name = f'Thesis Tilburg GNN/ResultsDF/Results_GCN_1963_Correlation(absolute)_Min_W{W_target}_theta{theta_target}.csv'
#
# NameError: name 'save_results' is not defined

# %%
file_name = f'Thesis Tilburg GNN/ResultsDF/Results_GCN_1963_Correlation(absolute)_Min_W{W_target}_theta{theta_target}.csv'

results_df.to_csv(file_name, index=False)
